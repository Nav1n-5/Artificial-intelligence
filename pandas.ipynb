# %% [markdown]
# <a href="https://colab.research.google.com/github/Nav1n-5/Artificial-intelligence/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
hh=df['households'].head()

# %%
hh.mean()
# Out:
# np.float64(308.0)

# %%
hh.std()
# Out:
# 155.11447385721294

# %%
hh.min()
# Out:
# 117.0

# %%
hh.describe()
# Out:
# count      5.000000
# mean     308.000000
# std      155.114474
# min      117.000000
# 25%      226.000000
# 50%      262.000000
# 75%      463.000000
# max      472.000000
# Name: households, dtype: float64

# %%
rel=df[['population',	'households']]
rel.head()
# Out:
#    population  households
# 0      1015.0       472.0
# 1      1129.0       463.0
# 2       333.0       117.0
# 3       515.0       226.0
# 4       624.0       262.0

# %%
rel.describe()
# Out:
#          population    households
# count  17000.000000  17000.000000
# mean    1429.573941    501.221941
# std     1147.852959    384.520841
# min        3.000000      1.000000
# 25%      790.000000    282.000000
# 50%     1167.000000    409.000000
# 75%     1721.000000    605.250000
# max    35682.000000   6082.000000

# %%
rel.hist()
# Out:
# array([[<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>]], dtype=object)

# %%
rel.plot.scatter('population','households')
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %%
 rel.loc[1]
# Out:
# population    1129.0
# households     463.0
# Name: 1, dtype: float64

# %%
total_bedrooms=df['total_bedrooms']
total_bedrooms.head()
# Out:
# 0    1283.0
# 1    1901.0
# 2     174.0
# 3     337.0
# 4     326.0
# Name: total_bedrooms, dtype: float64

# %%
total_bedrooms>225
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 16995     True
# 16996     True
# 16997     True
# 16998     True
# 16999     True
# Name: total_bedrooms, Length: 17000, dtype: bool

# %%
# !pip install names
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 18.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for names: filename=names-0.3.0-py3-none-any.whl size=803681 sha256=6cb052424ae80d54351b98df04d728920c78d03074ec3f0c07d0b62c36ee42a1
#   Stored in directory: /root/.cache/pip/wheels/8d/db/fc/50ec19a89a8dcbbd158a4aae44123cb525cda1f07dae287197
# Successfully built names
# ...

# %%
import names

df['random name'] = [names.get_full_name() for _ in range(len(df))]
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value       random name
# 0      1015.0       472.0         1.4936             66900.0     Michael Woods
# 1      1129.0       463.0         1.8200             80100.0  Harold Mcconnell
# 2       333.0       117.0         1.6509             85700.0      Anne Fuentes
# 3       515.0       226.0         3.1917             73400.0       Henry Combs
# 4       624.0       262.0         1.9250             65500.0    Michael Garner

# %%
pd.DataFrame(data={'name':[1,2,3],'age':[12,12,12]})
# Out:
#    name  age
# 0     1   12
# 1     2   12
# 2     3   12

# %% [markdown]
# creating our own dataframe
